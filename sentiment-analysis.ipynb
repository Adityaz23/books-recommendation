# %% [markdown]
# # This is the senitmental file where we will train the llm to different - different emotions like joy anger and etc.

# %%
import pandas as pd
books = pd.read_csv("books_with_categories.csv")
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 6139  9788173031014  8173031010
# 6140  9788179921623  817992162X
# 6141  9788185300535  8185300534
# 6142  9789027712059  9027712050
# 6143  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 6139                                Journey to the East
# 6140  The Monk Who Sold His Ferrari: A Fable About F...
# 6141                                          I Am that
# ...

# %%
# we will be treating the sentimental analysis as a text classification problem. We will use hugging face model for this aswell.
from transformers import pipeline

classifier = pipeline(task="text-classification", model="SamLowe/roberta-base-go_emotions", top_k=None, device="mps")

sentences = ["I think i have crush on someone}"]

model_outputs = classifier(sentences)
print(model_outputs[0])
# produces a list of dicts for each of the labels
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# ...

# %%
# books["description"][5]

# %%
classifier(books["description"][5])
# Out:
# [[{'label': 'neutral', 'score': 0.7419658303260803},
#   {'label': 'realization', 'score': 0.1369493156671524},
#   {'label': 'approval', 'score': 0.09110077470541},
#   {'label': 'disappointment', 'score': 0.022280389443039894},
#   {'label': 'annoyance', 'score': 0.015249023213982582},
#   {'label': 'admiration', 'score': 0.013294525444507599},
#   {'label': 'disapproval', 'score': 0.011003623716533184},
#   {'label': 'sadness', 'score': 0.008263121359050274},
#   {'label': 'disgust', 'score': 0.003915111999958754},
#   {'label': 'optimism', 'score': 0.003352390369400382},
#   {'label': 'confusion', 'score': 0.002450305037200451},
#   {'label': 'fear', 'score': 0.0018813037313520908},
#   {'label': 'embarrassment', 'score': 0.0016917991451919079},
#   {'label': 'anger', 'score': 0.0015422748401761055},
#   {'label': 'surprise', 'score': 0.001458858954720199},
#   {'label': 'relief', 'score': 0.0010335136903449893},
#   {'label': 'love', 'score': 0.0010275793028995395},
# ...

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'excitement', 'score': 0.49505096673965454},
#  {'label': 'admiration', 'score': 0.2984217405319214},
#  {'label': 'neutral', 'score': 0.11334912478923798},
#  {'label': 'approval', 'score': 0.06156667321920395},
#  {'label': 'surprise', 'score': 0.025452638044953346},
#  {'label': 'curiosity', 'score': 0.020611191168427467},
#  {'label': 'joy', 'score': 0.013649091124534607},
#  {'label': 'love', 'score': 0.012229576706886292},
#  {'label': 'desire', 'score': 0.012063363566994667},
#  {'label': 'optimism', 'score': 0.005851102992892265},
#  {'label': 'realization', 'score': 0.004697068128734827},
#  {'label': 'annoyance', 'score': 0.0029893338214606047},
#  {'label': 'pride', 'score': 0.002599795116111636},
#  {'label': 'confusion', 'score': 0.0024072828236967325},
#  {'label': 'amusement', 'score': 0.0021955508273094893},
#  {'label': 'disapproval', 'score': 0.0021141988690942526},
#  {'label': 'disappointment', 'score': 0.001981467939913273},
# ...

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'neutral', 'score': 0.9423109889030457},
#  {'label': 'approval', 'score': 0.03423655033111572},
#  {'label': 'realization', 'score': 0.024165352806448936},
#  {'label': 'annoyance', 'score': 0.006766472011804581},
#  {'label': 'admiration', 'score': 0.005985408555716276},
#  {'label': 'sadness', 'score': 0.005476201884448528},
#  {'label': 'disappointment', 'score': 0.004732154309749603},
#  {'label': 'optimism', 'score': 0.003723397385329008},
#  {'label': 'disapproval', 'score': 0.003488865913823247},
#  {'label': 'disgust', 'score': 0.002289121737703681},
#  {'label': 'fear', 'score': 0.0019254954531788826},
#  {'label': 'anger', 'score': 0.001611347426660359},
#  {'label': 'confusion', 'score': 0.0015487552154809237},
#  {'label': 'desire', 'score': 0.0014074408682063222},
#  {'label': 'caring', 'score': 0.0013327669585123658},
#  {'label': 'amusement', 'score': 0.0012335135834291577},
#  {'label': 'joy', 'score': 0.0011541954008862376},
# ...

# %%
predictions
# Out:
# [[{'label': 'excitement', 'score': 0.49505096673965454},
#   {'label': 'admiration', 'score': 0.2984217405319214},
#   {'label': 'neutral', 'score': 0.11334912478923798},
#   {'label': 'approval', 'score': 0.06156667321920395},
#   {'label': 'surprise', 'score': 0.025452638044953346},
#   {'label': 'curiosity', 'score': 0.020611191168427467},
#   {'label': 'joy', 'score': 0.013649091124534607},
#   {'label': 'love', 'score': 0.012229576706886292},
#   {'label': 'desire', 'score': 0.012063363566994667},
#   {'label': 'optimism', 'score': 0.005851102992892265},
#   {'label': 'realization', 'score': 0.004697068128734827},
#   {'label': 'annoyance', 'score': 0.0029893338214606047},
#   {'label': 'pride', 'score': 0.002599795116111636},
#   {'label': 'confusion', 'score': 0.0024072828236967325},
#   {'label': 'amusement', 'score': 0.0021955508273094893},
#   {'label': 'disapproval', 'score': 0.0021141988690942526},
#   {'label': 'disappointment', 'score': 0.001981467939913273},
# ...

# %%
sorted(predictions[0],key=lambda x:x["label"])
# Out:
# [{'label': 'admiration', 'score': 0.2984217405319214},
#  {'label': 'amusement', 'score': 0.0021955508273094893},
#  {'label': 'anger', 'score': 0.0012881984002888203},
#  {'label': 'annoyance', 'score': 0.0029893338214606047},
#  {'label': 'approval', 'score': 0.06156667321920395},
#  {'label': 'caring', 'score': 0.001193404896184802},
#  {'label': 'confusion', 'score': 0.0024072828236967325},
#  {'label': 'curiosity', 'score': 0.020611191168427467},
#  {'label': 'desire', 'score': 0.012063363566994667},
#  {'label': 'disappointment', 'score': 0.001981467939913273},
#  {'label': 'disapproval', 'score': 0.0021141988690942526},
#  {'label': 'disgust', 'score': 0.001436283579096198},
#  {'label': 'embarrassment', 'score': 0.0004494803724810481},
#  {'label': 'excitement', 'score': 0.49505096673965454},
#  {'label': 'fear', 'score': 0.001415332080796361},
#  {'label': 'gratitude', 'score': 0.0008985294844023883},
#  {'label': 'grief', 'score': 0.0004383956256788224},
# ...

# %%
import numpy as np
emotion_labels = ["anger","disgust","fear","joy","neutral","sadness","surprise","neutral"]
isbn = []
emotion_scores = {label:[] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
        per_emotion_scores = {label:[] for label in emotion_labels}
        for prediction in predictions:
                sorted_predictions = sorted(prediction, key=lambda x: x["label"])
                for index , label in enumerate(emotion_labels):
                        per_emotion_scores[label].append(sorted_predictions[index]["score"])
                return {label: np.max(scores) for label,scores in per_emotion_scores.items()}

# %%
for i in range (10):
        isbn.append(books["isbn13"][i])
        sentences = books["description"][i].split(".")
        predictions = classifier(sentences)
        max_scores = calculate_max_emotion_scores(predictions)
        for label in emotion_labels:
                emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.2984217405319214),
#   np.float64(0.842938244342804),
#   np.float64(0.8438476920127869),
#   np.float64(0.009910427033901215),
#   np.float64(0.001369174919091165),
#   np.float64(0.01607685349881649),
#   np.float64(0.8295944929122925),
#   np.float64(0.934485912322998),
#   np.float64(0.13989201188087463),
#   np.float64(0.0031212291214615107)],
#  'disgust': [np.float64(0.0021955508273094893),
#   np.float64(0.0008654151461087167),
#   np.float64(0.0005711785051971674),
#   np.float64(0.0010734617244452238),
#   np.float64(0.0024822058621793985),
#   np.float64(0.0019459299510344863),
#   np.float64(0.0005306174862198532),
#   np.float64(0.0007446648669429123),
#   np.float64(0.0011058931704610586),
#   np.float64(0.0025026702787727118)],
#  'fear': [np.float64(0.0012881984002888203),
#   np.float64(0.0007592067122459412),
#   np.float64(0.04729536175727844),
#   np.float64(0.0018201866187155247),
#   np.float64(0.002586043905466795),
# ...

# %%
from tqdm import tqdm
emotion_labels = ["anger","disgust","fear","joy","sadness","surprise","neutral"]
isbn = []
emotion_scores = {label:[] for label in emotion_labels}
for i in tqdm(range(len(books))):
        isbn.append(books["isbn13"][i])
        sentences = books["description"][i].split(".")
        predictions = classifier(sentences)
        max_scores = calculate_max_emotion_scores(predictions)
        for label in emotion_labels:
                emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 6144/6144 [13:55<00:00,  7.35it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.298422  0.002196  0.001288  0.002989  0.061567  0.001193  0.002407
# 1     0.842938  0.000865  0.000759  0.003019  0.069412  0.000946  0.000878
# 2     0.843848  0.000571  0.047295  0.037732  0.067532  0.005412  0.002649
# 3     0.009910  0.001073  0.001820  0.004106  0.177686  0.002314  0.004595
# 4     0.001369  0.002482  0.002586  0.011019  0.016053  0.002355  0.001801
# ...        ...       ...       ...       ...       ...       ...       ...
# 6139  0.918175  0.002467  0.000940  0.002384  0.068051  0.001374  0.001620
# 6140  0.413401  0.003701  0.001166  0.003801  0.252189  0.040689  0.001396
# 6141  0.821012  0.000477  0.001257  0.004982  0.158923  0.004406  0.001251
# 6142  0.342617  0.000475  0.000438  0.002393  0.473998  0.005641  0.002093
# 6143  0.846255  0.003099  0.001774  0.003541  0.044227  0.006023  0.001088
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# ...

# %%
books = pd.merge(books,emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 6139  9788173031014  8173031010
# 6140  9788179921623  817992162X
# 6141  9788185300535  8185300534
# 6142  9789027712059  9027712050
# 6143  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 6139                                Journey to the East
# 6140  The Monk Who Sold His Ferrari: A Fable About F...
# 6141                                          I Am that
# ...

# %%
books.to_csv("books_with_emotions.csv",index=False)
